# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("budgetwise_finance_dataset.csv")

# %%
df.head()
# Out:
#   transaction_id user_id        date transaction_type       category amount  \
# 0          T4999    U018  2023-04-25          Expense       Educaton   3888
# 1         T12828    U133  08/05/2022          Expense           rent    649
# 2          T7403    U091    31-12-23           Income      Freelance  13239
# 3         T12350    U097         NaN          Expense            Fod   6299
# 4          T7495    U088  10/28/2022          Expense  entertainment   2287
#
#     payment_mode   location             notes
# 0           card  Ahmedabad     Movie tickets
# 1            NaN  Hyderabad            asdfgh
# 2            Csh        BAN             Books
# 3  Bank Transfer  AHMEDABAD  Electricity bill
# 4           CARD  Hyderabad               NaN

# %%
df.isnull().sum()
# Out:
# transaction_id         0
# user_id                0
# date                 486
# transaction_type       0
# category             285
# amount               291
# payment_mode         808
# location            1262
# notes               2821
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15900 entries, 0 to 15899
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   transaction_id    15900 non-null  str
#  1   user_id           15900 non-null  str
#  2   date              15414 non-null  str
#  3   transaction_type  15900 non-null  str
#  4   category          15615 non-null  str
#  5   amount            15609 non-null  str
#  6   payment_mode      15092 non-null  str
#  7   location          14638 non-null  str
#  8   notes             13079 non-null  str
# dtypes: str(9)
# memory usage: 1.1 MB

# %%
df.describe()
# Out:
#        transaction_id user_id        date transaction_type category  amount  \
# count           15900   15900       15414            15900    15615   15609
# unique          14000     150        5025                2       46   11165
# top             T8639    U036  2024-08-13          Expense     FOOD  999999
# freq                5     136          14            13517      583      80
#
#        payment_mode location             notes
# count         15092    14638             13079
# unique           19       40                26
# top             UPI      PUN  Electricity bill
# freq            939      398               561

# %%
sns.countplot(x = df["amount"])
# Out:
# <Axes: xlabel='amount', ylabel='count'>
